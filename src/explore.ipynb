# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv

# load the .env file variables
load_dotenv()
# Out:
# True

# %%
client_id = os.environ.get('CLIENT_ID')
client_secret = os.environ.get('CLIENT_SECRET')

# %%
# Acá ya tenemos una conexión con spotify
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials

con = spotipy.Spotify(auth_manager= SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
id_artista = '0k17h0D3J5VfsdmQ1iZtE9'

response = con.artist_top_tracks(id_artista)

print(response['tracks'])
# Out:
# [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'}, 'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9', 'id': '0k17h0D3J5VfsdmQ1iZtE9', 'name': 'Pink Floyd', 'type': 'artist', 'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5Dbax7G8SWrP9xyzkOvy2F'}, 'href': 'https://api.spotify.com/v1/albums/5Dbax7G8SWrP9xyzkOvy2F', 'id': '5Dbax7G8SWrP9xyzkOvy2F', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2735d48e2f56d691f9a4e4b0bdf', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e025d48e2f56d691f9a4e4b0bdf', 'height': 300, 'width': 300}, {'url': 'https://i.scdn.co/image/ab67616d000048515d48e2f56d691f9a4e4b0bdf', 'height': 64, 'width': 64}], 'is_playable': True, 'name': 'The Wall', 'release_date': '1979-11-30', 'release_date_precision': 'day', 'total_tracks': 26, 'type': 'album', 'uri': 'spotify:album:5Dbax7G8SWrP9xyzkOvy2F'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'}, 'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9', 'id': '0k17h0D3J5VfsdmQ1iZtE9', 'name': 'Pink Floyd', 'type': 'artist', 'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'disc_number': 1, 'duration_ms': 238746, 'explicit': False, 'external_ids': {'isrc': 'GBN9Y1100099'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4gMgiXfqyzZLMhsksGmbQV'}, 'href': 'https://api.spotify.com/v1/tracks/4gMgiXfqyzZLMhsksGmbQV', 'id': '4gMgiXfqyzZLMhsksGmbQV', 'is_local': False, 'is_playable': True, 'name': 'Another Brick in the Wall, Pt. 2', 'popularity': 81, 'preview_url': None, ...

# %%
df_tracks = pd.DataFrame.from_records(response['tracks'])

df_tracks
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
# 5  [{'external_urls': {'spotify': 'https://open.s...
# 6  [{'external_urls': {'spotify': 'https://open.s...
# 7  [{'external_urls': {'spotify': 'https://open.s...
# 8  [{'external_urls': {'spotify': 'https://open.s...
# 9  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            2
# 3  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 5  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 6  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 7  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            2
# 8  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 9  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#    duration_ms  explicit              external_ids  \
# 0       238746     False  {'isrc': 'GBN9Y1100099'}
# 1       334743     False  {'isrc': 'GBN9Y1100088'}
# 2       382296     False  {'isrc': 'GBN9Y1100113'}
# 3       169534     False  {'isrc': 'GBN9Y1100077'}
# 4       413947     False  {'isrc': 'GBN9Y1100079'}
# 5       382834      True  {'isrc': 'GBN9Y1100081'}
# 6       283872     False  {'isrc': 'GBN9Y1100080'}
# 7       278440     False  {'isrc': 'GBN9Y1100108'}
# 8       209956     False  {'isrc': 'GBN9Y1100103'}
# 9       307733     False  {'isrc': 'GBN9Y1100087'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/4g...
# 1  {'spotify': 'https://open.spotify.com/track/6m...
# 2  {'spotify': 'https://open.spotify.com/track/5H...
# 3  {'spotify': 'https://open.spotify.com/track/2c...
# 4  {'spotify': 'https://open.spotify.com/track/3T...
# 5  {'spotify': 'https://open.spotify.com/track/0v...
# 6  {'spotify': 'https://open.spotify.com/track/2T...
# 7  {'spotify': 'https://open.spotify.com/track/7F...
# 8  {'spotify': 'https://open.spotify.com/track/3x...
# 9  {'spotify': 'https://open.spotify.com/track/3C...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/4gMgiXfqyzZL...  4gMgiXfqyzZLMhsksGmbQV
# 1  https://api.spotify.com/v1/tracks/6mFkJmJqdDVQ...  6mFkJmJqdDVQ1REhVfGgd1
# 2  https://api.spotify.com/v1/tracks/5HNCy40Ni5BZ...  5HNCy40Ni5BZJFw1TKzRsC
# 3  https://api.spotify.com/v1/tracks/2ctvdKmETyOz...  2ctvdKmETyOzPb2GiJJT53
# 4  https://api.spotify.com/v1/tracks/3TO7bbrUKrOS...  3TO7bbrUKrOSPGRTB5MeCz
# 5  https://api.spotify.com/v1/tracks/0vFOzaXqZHah...  0vFOzaXqZHahrZp6enQwQb
# 6  https://api.spotify.com/v1/tracks/2TjdnqlpwOjh...  2TjdnqlpwOjhijHCwHCP2d
# 7  https://api.spotify.com/v1/tracks/7F02x6EKYIQV...  7F02x6EKYIQV3VcTaTm7oN
# 8  https://api.spotify.com/v1/tracks/3xGJuHvSxFJx...  3xGJuHvSxFJxxYlHj5BIoT
# 9  https://api.spotify.com/v1/tracks/3CmHvyZQQAGk...  3CmHvyZQQAGkKkTjTBFWN6
#
#    is_local  is_playable                              name  popularity  \
# 0     False         True  Another Brick in the Wall, Pt. 2          81
# 1     False         True                Wish You Were Here          80
# 2     False         True                  Comfortably Numb          79
# 3     False         True              Breathe (In the Air)          77
# 4     False         True                              Time          74
# 5     False         True                             Money          74
# 6     False         True          The Great Gig in the Sky          74
# 7     False         True                           Hey You          72
# 8     False         True                        Young Lust          71
# 9     False         True                      Have a Cigar          70
#
#   preview_url  track_number   type                                   uri
# 0        None             5  track  spotify:track:4gMgiXfqyzZLMhsksGmbQV
# 1        None             4  track  spotify:track:6mFkJmJqdDVQ1REhVfGgd1
# 2        None             6  track  spotify:track:5HNCy40Ni5BZJFw1TKzRsC
# 3        None             2  track  spotify:track:2ctvdKmETyOzPb2GiJJT53
# 4        None             4  track  spotify:track:3TO7bbrUKrOSPGRTB5MeCz
# 5        None             6  track  spotify:track:0vFOzaXqZHahrZp6enQwQb
# 6        None             5  track  spotify:track:2TjdnqlpwOjhijHCwHCP2d
# 7        None             1  track  spotify:track:7F02x6EKYIQV3VcTaTm7oN
# 8        None             9  track  spotify:track:3xGJuHvSxFJxxYlHj5BIoT
# 9        None             3  track  spotify:track:3CmHvyZQQAGkKkTjTBFWN6

# %%
diagrama_correlacion = sns.scatterplot(data=df_tracks,x='popularity',y='duration_ms')

fig = diagrama_correlacion.get_figure()
fig.savefig('scattter.png')
